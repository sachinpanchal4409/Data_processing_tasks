# %%
from PIL import Image
import numpy as np
import cv2
pred = np.load('C:/SachinP/Paper4_LASkipModel/Revision_Comparison Papers/orderedpatches_imgs64_DRIVE_train.npy')
#gt = np.load('C:/SachinP/WinSCP_transfers/GPU2/Segmentation/DRIVE_datasets_training_testing/origin.npy')

print("Shape of dataset :",pred.shape)
#gt.shape
pred1=np.transpose(pred,(0,2,3,1))
pred1.shape

#gt1=np.transpose(gt,(0,2,3,1))
#gt1.shape

from PIL import Image as im
pred2 = np.array(pred1, dtype=np.float64)
print("Shape of an image: ",pred2[1].shape)
pred3=pred2[0]*255
#print(pred3)
#gt2 = np.array(gt1, dtype=np.float64)
#gt3=pred2[0]

#diff=gt3-pred3
from matplotlib import pyplot as plt
for i in range(5):
    
    plt.axis('off')
    plt.imshow(pred2[i]*255,aspect='equal')
    
    #plt.imsave("C:/SachinP/Paper4_LASkipModel/DRIVE_Predicted_Out/DRIVE_Original/DRIVE_mask"+str(i+100)+".png",pred2[i]*255)
    plt.savefig("C:/SachinP/Paper4_LASkipModel/DRIVE_Predicted_Out/DRIVE_Original/DRIVE_mask"+str(i+200)+".png")
    
plt.show()
# Out:
# Shape of dataset : (320, 1, 128, 128)
# Shape of an image:  (128, 128, 1)

# %%
from PIL import Image as im
print(type(pred2[1]))
print(pred2[1].shape)
data = np.squeeze(pred2[1])
print(data.shape)
img = Image.fromarray(data,"RGB")
img.save('asasas.png')
# Out:
# <class 'numpy.ndarray'>
# (64, 64, 1)
# (64, 64)

# %%
display(pred11)
# Out:
# array([[[4.14220797e-10],
#         [2.34478686e-10],
#         [8.25725543e-10],
#         ...,
#         [2.35928894e-15],
#         [1.09009159e-15],
#         [1.01515066e-16]],
#
#        [[6.71078991e-12],
#         [2.25619731e-11],
#         [1.26829242e-14],
#         ...,
#         [7.41440708e-16],
#         [1.82355357e-17],
#         [8.65860478e-16]],
#
#        [[3.70847034e-11],
#         [6.72182240e-11],
#         [3.44180759e-14],
#         ...,
#         [1.33366190e-17],
#         [7.19398979e-18],
#         [3.06421792e-16]],
#
#        ...,
#
#        [[2.46200092e-11],
#         [1.45574037e-12],
#         [3.44452792e-13],
#         ...,
#         [8.51641934e-12],
#         [3.11748846e-15],
#         [3.08579759e-11]],
#
#        [[1.27744221e-11],
#         [4.76531141e-12],
#         [6.97950161e-12],
#         ...,
#         [1.54312313e-13],
#         [3.20570207e-17],
#         [6.46654903e-14]],
#
#        [[2.84940778e-12],
# ...
